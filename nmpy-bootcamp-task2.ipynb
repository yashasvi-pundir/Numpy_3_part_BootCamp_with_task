# %% [markdown]
# <a href="https://www.kaggle.com/code/yashasvipundir/nmpy-bootcamp-task2?scriptVersionId=240017741" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ###`Q-1:` Find the nearest element in the array to a given integer.
# ```
# Ex:-
# a=23 and array - [10 17 24 31 38 45 52 59].
# Nearest element is 24
# ```
# Hint: Read about this function `argmin()`

# %%
# code here
import numpy as np
arr=np.array([10,17, 24 ,31 ,38 ,45, 52 ,59])
a=21
arr[abs(arr-a).argmin()]
# Out:
# 24

# %% [markdown]
# ###`Q-2:` Replace multiples of 3 or 5 as 0 in the given array.
# ```
# arr=[1 2 3 4 5 6 7 9]
#
# result-> [1 2 0 4 0 0 7 0]
# ```

# %%
# code here
ar=[1,2,3,4,5,6,7,9]
arr = np.array(ar)
arr=np.where((arr%3==0) | (arr%5==0) ,0,arr)
arr
# Out:
# array([1, 2, 0, 4, 0, 0, 7, 0])

# %% [markdown]
# ###`Q-3:` Use Fancy Indexing.
# 1. Double the array elements at  given indexes
# ```
# arr = np.arrange(10)
# indexes = [0,3,4,9]
# ```
# Result -> `[ 0  1  2  6  8  5  6  7  8 18]`
#
# 2. Using a given array make a different array as in below example
# ```
# array = [1,2,3]
# result array -> [1 1 1 2 2 2 3 3 3]
# ```
# * Internal-repetion should be as length of the array.
#
# Hint:
# ```
# if a is an array
# a = [2,4]
# a[[1,1,0,1]] will result in-> [4 4 2 4]
# ```

# %%
# code here
arr = np.arange(10)
arr[[0,3,4,9]]*=2
arr
# Out:
# array([ 0,  1,  2,  6,  8,  5,  6,  7,  8, 18])

# %%
array = [1,2,3]
a=np.array(array)
result=np.repeat(a,3)
result
# Out:
# array([1, 1, 1, 2, 2, 2, 3, 3, 3])

# %% [markdown]
# .###`Q-4:` Your are given an array which is havig some nan value. You job is to fill those nan values with most common element in the array.
# ```
# arr=np.array([[1,2,np.nan],[4,2,6],[np.nan,np.nan,5]])
#
# ```

# %%
# code here
arr=np.array([[1,2,np.nan],[4,2,6],[np.nan,np.nan,5]])
non_nan_values=arr[~(np.isnan(arr))]
unique,counts=np.unique(non_nan_values,return_counts=True)
most_common_element=unique[np.argmax(counts)]
arr[(np.isnan(arr))]=most_common_element
arr
# Out:
# array([[1., 2., 2.],
#        [4., 2., 6.],
#        [2., 2., 5.]])

# %% [markdown]
# ### `Q-5:` Write a NumPy program
#
# - to find the missing data in a given array. Return a boolean matrix.
# - also try to fill those missing values with 0. For that, you can use `np.nan_to_num(a)`
#
# ```python
# import numpy as np
#
# np.array([[3, 2, np.nan, 1],
#           [10, 12, 10, 9],
#           [5, np.nan, 1, np.nan]])
# ```

# %%
# code here
arr=np.array([[3, 2, np.nan, 1],
          [10, 12, 10, 9],
          [5, np.nan, 1, np.nan]])
(np.isnan(arr))
# Out:
# array([[False, False,  True, False],
#        [False, False, False, False],
#        [False,  True, False,  True]])

# %%
np.nan_to_num(arr)
# Out:
# array([[ 3.,  2.,  0.,  1.],
#        [10., 12., 10.,  9.],
#        [ 5.,  0.,  1.,  0.]])

# %% [markdown]
# ###`Q-6:` Given two arrays, X and Y, construct the Cauchy matrix C.
# `Cij =1/(xi - yj)`
#
# http://en.wikipedia.org/wiki/Cauchy_matrix
# ```
# x = numpy.array([1,2,3,4]).reshape((-1, 1)
# y = numpy.array([5,6,7])
# ```

# %%
# code here
x = np.array([1,2,3,4]).reshape((-1, 1))
y = np.array([5,6,7])
1/(x-y)
# Out:
# array([[-0.25      , -0.2       , -0.16666667],
#        [-0.33333333, -0.25      , -0.2       ],
#        [-0.5       , -0.33333333, -0.25      ],
#        [-1.        , -0.5       , -0.33333333]])

# %% [markdown]
# ###`Q-7:` Plot this below equation.
#
# $$\large y = \frac{e^x - e^{-x}}{e^x + e^{-x}}$$
#
# **Note: This equation is called tanh activation function. In deep learning, many times this function is used. If you find some difference between the sigmoid function and this tanh function, note that to your notebook.**

# %%
# code here
import matplotlib.pyplot as plt
x=np.linspace(-50,50,100)
y=(np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))
plt.plot(x,y)

# %% [markdown]
# ### `Q-8:` Plot the below equation.
#
# $$\large y = \sqrt{36 - (x - 4)^2} + 2$$
#
# The range of x should be between -2 to 10. $x ∈ [-2, 10]$

# %%
# code here
x=np.linspace(-2,10,100)
y=np.sqrt(36-(x-4)**2)+2
plt.plot(x,y)

# %% [markdown]
# ### `Q-9:` Write a program implement Boradcasting Rule to check if two array can be added or not.
# Given tuples of shapes.
# ```
# shape of a- (3,2,2)
# shape of b- (2,2)
#
# check_broadcast(a, b) -> return Boolean (True if can broadcasted, False other wise.)
# ```

# %%
# code here
def broadcast(a,b):
    a=a[::-1]
    b=b[::-1]
    for ai,bi in zip(a,b):
        # zip() ek Python function hai jo do (ya zyada) iterables ko ek saath pair karta hai,
        #  item by item. Yeh un items ko tuple ke form mein combine karta hai.
        # Tumhare code mein a aur b do sequences hain (reverse lists ya strings) aur zip(a, b)
        #  unko ek saath loop karne ke liye use kiya ja raha hai.
        if ai!=bi and ai!=1 and bi!=1:
            return False
        return

# a = [1, 2, 3]
# b = [4, 5, 6]

# for ai, bi in zip(a, b):
#     print(ai, bi)
# 1 4
# 2 5
# 3 6
